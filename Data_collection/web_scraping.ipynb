# %%
import requests

URL = "https://www.scrapethissite.com/pages/simple/"
res = requests.get(URL)

# %%
if res.status_code == 200:
    print(res.headers)  # prints metadata like content type, server, info

with open("scraped_data/data1.html", "w", encoding="utf-8") as f:
    f.write(res.text)
# Out:
# {'Date': 'Sun, 09 Aug 2026 09:11:58 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Nel': '{"report_to":"heroku-nel","response_headers":["Via"],"max_age":3600,"success_fraction":0.01,"failure_fraction":0.1}', 'Report-To': '{"group":"heroku-nel","endpoints":[{"url":"https://nel.heroku.com/reports?s=7qKqXji0fF6%2FSJcT01OOLZSaoy2UIsLtBHd9QcDjxYE%3D\\u0026sid=67ff5de4-ad2b-4112-9289-cf96be89efed\\u0026ts=1786266718"}],"max_age":3600}', 'Reporting-Endpoints': 'heroku-nel="https://nel.heroku.com/reports?s=7qKqXji0fF6%2FSJcT01OOLZSaoy2UIsLtBHd9QcDjxYE%3D&sid=67ff5de4-ad2b-4112-9289-cf96be89efed&ts=1786266718"', 'Server': 'cloudflare', 'Via': '1.1 heroku-router', 'cf-cache-status': 'DYNAMIC', 'Content-Encoding': 'zstd', 'CF-RAY': 'a285a2ecca965cd5-SIN', 'alt-svc': 'h3=":443"; ma=86400'}

# %%
# BEAUTIFULSOUP 
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\hp\anaconda3\lib\site-packages (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hp\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\hp\anaconda3\lib\site-packages (from beautifulsoup4) (4.15.0)

# %%
from bs4 import BeautifulSoup

with open("scraped_data/data1.html", "r") as f:
    html_content = f.read()



soup = BeautifulSoup(html_content, "lxml")

# %%
# find() -  to find values
soup.find("h3")
soup.h3

# find_all() - to find all
all_h3 = soup.find_all("h3")

for h3 in all_h3:
    name = h3.get_text(strip=True)

#find_parent()- to find the parent element 
    print(h3.find_parent("div")["class"])

#find_next() - to find the next element value
# select & select_one
     population = h3.find_next("div").select("span.country-population")[0].get_text(strip=True)
     print( h3.find_next("div").select_one("span.country-population").get_text(strip=True))


# Attributes
     print(h3.attrs)
