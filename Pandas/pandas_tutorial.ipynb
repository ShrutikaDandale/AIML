# %%
import pandas as pd

# %%
info = {
    "Name" : ["RM", "Suga", "Jimin"],
    "CGPA" : [9.1, 9.21, 9.45]
}

df = pd.DataFrame(info) #dataframe will convert the raw data into table form

print(df)
# Out:
#     Name  CGPA
# 0     RM  9.10
# 1   Suga  9.21
# 2  Jimin  9.45

# %%
df
# Out:
#     Name  CGPA
# 0     RM  9.10
# 1   Suga  9.21
# 2  Jimin  9.45
